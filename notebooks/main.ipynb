# %%
import os
os.chdir("..")

# %% [markdown]
# # 環境安裝

# %%
# !conda create -n deepsvg python=3.7
# !conda activate deepsvg
# Out:
# ^C
# Could not find conda environment: deepsvg
# You can list all discoverable environments with `conda info --envs`.

# %%
# !pip install https://download.pytorch.org/whl/cu101/torch-1.4.0-cp38-cp38-win_amd64.whl
# Out:
# Requirement already satisfied: torch==1.4.0 from https://download.pytorch.org/whl/cu101/torch-1.4.0-cp38-cp38-win_amd64.whl in c:\users\cg\anaconda3_ai\lib\site-packages (1.4.0)

# %%
# !pip install torch==1.4.0
# Out:
# Requirement already satisfied: torch==1.4.0 in c:\users\cg\anaconda3_ai\lib\site-packages (1.4.0)

# %%
# !pip install torchvision==0.5.0
# Out:
# Collecting torchvision==0.5.0
#   Using cached torchvision-0.5.0-cp38-cp38-win_amd64.whl (1.2 MB)
# Requirement already satisfied: numpy in c:\users\cg\anaconda3_ai\lib\site-packages (from torchvision==0.5.0) (1.18.5)
# Requirement already satisfied: pillow>=4.1.1 in c:\users\cg\anaconda3_ai\lib\site-packages (from torchvision==0.5.0) (7.2.0)
# Requirement already satisfied: six in c:\users\cg\anaconda3_ai\lib\site-packages (from torchvision==0.5.0) (1.15.0)
# Requirement already satisfied: torch==1.4.0 in c:\users\cg\anaconda3_ai\lib\site-packages (from torchvision==0.5.0) (1.4.0)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.5.0

# %%
# !pip install numpy==1.16.1
# Out:
# Collecting numpy==1.16.1
#   Using cached numpy-1.16.1.zip (5.1 MB)
# Building wheels for collected packages: numpy
#   Building wheel for numpy (setup.py): started
#   Building wheel for numpy (setup.py): finished with status 'error'
#   Running setup.py clean for numpy
# Failed to build numpy
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
#     Running setup.py install for numpy: started
#     Running setup.py install for numpy: finished with status 'error'
#   Rolling back uninstall of numpy
#   Moving to c:\users\cg\anaconda3_ai\lib\site-packages\numpy
#    from C:\Users\cg\anaconda3_AI\Lib\site-packages\~umpy
#   Moving to c:\users\cg\anaconda3_ai\lib\site-packages\numpy-1.18.5-py3.8.egg-info
#    from C:\Users\cg\anaconda3_AI\Lib\site-packages\~umpy-1.18.5-py3.8.egg-info
#   Moving to c:\users\cg\anaconda3_ai\scripts\f2py-script.py
#    from C:\Users\cg\AppData\Local\Temp\pip-uninstall-07m7nt_w\f2py-script.py
#   Moving to c:\users\cg\anaconda3_ai\scripts\f2py.exe
#    from C:\Users\cg\AppData\Local\Temp\pip-uninstall-07m7nt_w\f2py.exe
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\cg\anaconda3_AI\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\cg\\AppData\\Local\\Temp\\pip-install-ztrvm_2a\\numpy\\setup.py'"'"'; __file__='"'"'C:\\Users\\cg\\AppData\\Local\\Temp\\pip-install-ztrvm_2a\\numpy\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\cg\AppData\Local\Temp\pip-wheel-5611tzb1'
#        cwd: C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\
#   Complete output (308 lines):
#   Running from numpy source directory.
#   C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\misc_util.py:476: SyntaxWarning: "is" with a literal. Did you mean "=="?
#     return is_string(s) and ('*' in s or '?' is s)
#   blas_opt_info:
#   blas_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries mkl_rt not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#     NOT AVAILABLE
#
#   blis_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries blis not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#     NOT AVAILABLE
#
#   openblas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#   get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#   customize GnuFCompiler
#   Could not locate executable g77
#   Could not locate executable f77
#   customize IntelVisualFCompiler
#   Could not locate executable ifort
#   Could not locate executable ifl
#   customize AbsoftFCompiler
#   Could not locate executable f90
#   customize CompaqVisualFCompiler
#   Could not locate executable DF
#   customize IntelItaniumVisualFCompiler
#   Could not locate executable efl
#   customize Gnu95FCompiler
#   Could not locate executable gfortran
#   Could not locate executable f95
#   customize G95FCompiler
#   Could not locate executable g95
#   customize IntelEM64VisualFCompiler
#   customize IntelEM64TFCompiler
#   Could not locate executable efort
#   Could not locate executable efc
#   customize PGroupFlangCompiler
#   Could not locate executable flang
#   don't know how to compile Fortran code on platform 'nt'
#     NOT AVAILABLE
#
#   atlas_3_10_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#     NOT AVAILABLE
#
#   atlas_3_10_blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#     NOT AVAILABLE
#
#   atlas_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#     NOT AVAILABLE
#
#   atlas_blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#     NOT AVAILABLE
#
#   accelerate_info:
#     NOT AVAILABLE
#
#   C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\system_info.py:636: UserWarning:
#       Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [atlas]) or by setting
#       the ATLAS environment variable.
#     self.calc_info()
#   blas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries blas not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#     NOT AVAILABLE
#
#   C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\system_info.py:636: UserWarning:
#       Blas (http://www.netlib.org/blas/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [blas]) or by setting
#       the BLAS environment variable.
#     self.calc_info()
#   blas_src_info:
#     NOT AVAILABLE
#
#   C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\system_info.py:636: UserWarning:
#       Blas (http://www.netlib.org/blas/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [blas_src]) or by setting
#       the BLAS_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   'svnversion' 不是內部或外部命令、可執行的程式或批次檔。
#   non-existing path in 'numpy\\distutils': 'site.cfg'
#   lapack_opt_info:
#   lapack_mkl_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries mkl_rt not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#     NOT AVAILABLE
#
#   openblas_lapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#     NOT AVAILABLE
#
#   openblas_clapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries openblas,lapack not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#     NOT AVAILABLE
#
#   atlas_3_10_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\cg\anaconda3_AI\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\Users\cg\anaconda3_AI\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\cg\anaconda3_AI\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries tatlas,tatlas not found in C:\Users\cg\anaconda3_AI\libs
#   <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#     NOT AVAILABLE
#
#   atlas_3_10_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\cg\anaconda3_AI\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\Users\cg\anaconda3_AI\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\cg\anaconda3_AI\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries satlas,satlas not found in C:\Users\cg\anaconda3_AI\libs
#   <class 'numpy.distutils.system_info.atlas_3_10_info'>
#     NOT AVAILABLE
#
#   atlas_threads_info:
#   Setting PTATLAS=ATLAS
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\cg\anaconda3_AI\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\Users\cg\anaconda3_AI\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\cg\anaconda3_AI\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in C:\Users\cg\anaconda3_AI\libs
#   <class 'numpy.distutils.system_info.atlas_threads_info'>
#     NOT AVAILABLE
#
#   atlas_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\cg\anaconda3_AI\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\Users\cg\anaconda3_AI\lib
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack_atlas not found in C:\Users\cg\anaconda3_AI\libs
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries f77blas,cblas,atlas not found in C:\Users\cg\anaconda3_AI\libs
#   <class 'numpy.distutils.system_info.atlas_info'>
#     NOT AVAILABLE
#
#   lapack_info:
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#     libraries lapack not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#     NOT AVAILABLE
#
#   C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\system_info.py:636: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [lapack]) or by setting
#       the LAPACK environment variable.
#     self.calc_info()
#   lapack_src_info:
#     NOT AVAILABLE
#
#   C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\system_info.py:636: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#       the LAPACK_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   C:\Users\cg\anaconda3_AI\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running config_cc
#   unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   build_src
#   building py_modules sources
#   creating build
#   creating build\src.win-amd64-3.8
#   creating build\src.win-amd64-3.8\numpy
#   creating build\src.win-amd64-3.8\numpy\distutils
#   building library "npymath" sources
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.27.29110\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Users\cg\anaconda3_AI\include -IC:\Users\cg\anaconda3_AI\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.27.29110\include -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.6.1\include\um /Tc_configtest.c /Fo_configtest.obj
#   C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.27.29110\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /MANIFEST:EMBED,ID=1 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.27.29110\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\NETFXSDK\4.6.1\lib\um\x64 _configtest.obj /OUT:_configtest.exe
#   LINK : fatal error LNK1104: 無法開啟檔案 'kernel32.lib'
#   failure.
#   removing: _configtest.c _configtest.obj _configtest.obj.d
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\setup.py", line 415, in <module>
#       setup_package()
#     File "C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\setup.py", line 407, in setup_package
#       setup(**metadata)
#     File "C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\core.py", line 171, in setup
#       return old_setup(**new_attr)
#     File "C:\Users\cg\anaconda3_AI\lib\site-packages\setuptools\__init__.py", line 165, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\cg\anaconda3_AI\lib\distutils\core.py", line 148, in setup
#       dist.run_commands()
#     File "C:\Users\cg\anaconda3_AI\lib\distutils\dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\cg\anaconda3_AI\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\cg\anaconda3_AI\lib\site-packages\wheel\bdist_wheel.py", line 223, in run
#       self.run_command('build')
#     File "C:\Users\cg\anaconda3_AI\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\cg\anaconda3_AI\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\command\build.py", line 47, in run
#       old_build.run(self)
#     File "C:\Users\cg\anaconda3_AI\lib\distutils\command\build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "C:\Users\cg\anaconda3_AI\lib\distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\cg\anaconda3_AI\lib\distutils\dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\command\build_src.py", line 148, in run
#       self.build_sources()
#     File "C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\command\build_src.py", line 159, in build_sources
#       self.build_library_sources(*libname_info)
#     File "C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\command\build_src.py", line 292, in build_library_sources
#       sources = self.generate_sources(sources, (lib_name, build_info))
#     File "C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\command\build_src.py", line 375, in generate_sources
#       source = func(extension, build_dir)
#     File "numpy\core\setup.py", line 667, in get_mathlib_info
#       raise RuntimeError("Broken toolchain: cannot link a simple C program")
#   RuntimeError: Broken toolchain: cannot link a simple C program
#   ----------------------------------------
#   ERROR: Failed building wheel for numpy
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\cg\anaconda3_AI\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\cg\\AppData\\Local\\Temp\\pip-install-ztrvm_2a\\numpy\\setup.py'"'"'; __file__='"'"'C:\\Users\\cg\\AppData\\Local\\Temp\\pip-install-ztrvm_2a\\numpy\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' clean --all
#        cwd: C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy
#   Complete output (10 lines):
#   Running from numpy source directory.
#
#   `setup.py clean` is not supported, use one of the following instead:
#
#     - `git clean -xdf` (cleans all files)
#     - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                         files that aren't checked into the git repo)
#
#   Add `--force` to your command to use it anyway if you must (unsupported).
#
#   ----------------------------------------
#   ERROR: Failed cleaning build dir for numpy
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\cg\anaconda3_AI\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\cg\\AppData\\Local\\Temp\\pip-install-ztrvm_2a\\numpy\\setup.py'"'"'; __file__='"'"'C:\\Users\\cg\\AppData\\Local\\Temp\\pip-install-ztrvm_2a\\numpy\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\cg\AppData\Local\Temp\pip-record-m6bh68zq\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\cg\anaconda3_AI\Include\numpy'
#          cwd: C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\
#     Complete output (315 lines):
#     Running from numpy source directory.
#
#     Note: if you need reliable uninstall behavior, then install
#     with pip instead of using `setup.py install`:
#
#       - `pip install .`       (from a git repo or downloaded source
#                                release)
#       - `pip install numpy`   (last NumPy release on PyPi)
#
#
#     blas_opt_info:
#     blas_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#       NOT AVAILABLE
#
#     blis_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blis not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#       NOT AVAILABLE
#
#     openblas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#     get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#     customize GnuFCompiler
#     Could not locate executable g77
#     Could not locate executable f77
#     customize IntelVisualFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifl
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     customize CompaqVisualFCompiler
#     Could not locate executable DF
#     customize IntelItaniumVisualFCompiler
#     Could not locate executable efl
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize G95FCompiler
#     Could not locate executable g95
#     customize IntelEM64VisualFCompiler
#     customize IntelEM64TFCompiler
#     Could not locate executable efort
#     Could not locate executable efc
#     customize PGroupFlangCompiler
#     Could not locate executable flang
#     don't know how to compile Fortran code on platform 'nt'
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\system_info.py:636: UserWarning:
#         Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [atlas]) or by setting
#         the ATLAS environment variable.
#       self.calc_info()
#     blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blas not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#       NOT AVAILABLE
#
#     C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\system_info.py:636: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       self.calc_info()
#     blas_src_info:
#       NOT AVAILABLE
#
#     C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\system_info.py:636: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     'svnversion' 不是內部或外部命令、可執行的程式或批次檔。
#     non-existing path in 'numpy\\distutils': 'site.cfg'
#     lapack_opt_info:
#     lapack_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas,lapack not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\cg\anaconda3_AI\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\Users\cg\anaconda3_AI\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\cg\anaconda3_AI\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\Users\cg\anaconda3_AI\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\cg\anaconda3_AI\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\Users\cg\anaconda3_AI\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\cg\anaconda3_AI\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\Users\cg\anaconda3_AI\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\cg\anaconda3_AI\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\cg\anaconda3_AI\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\cg\anaconda3_AI\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\cg\anaconda3_AI\libs
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\cg\anaconda3_AI\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\Users\cg\anaconda3_AI\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\cg\anaconda3_AI\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\Users\cg\anaconda3_AI\libs
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack not found in ['C:\\Users\\cg\\anaconda3_AI\\lib', 'C:\\', 'C:\\Users\\cg\\anaconda3_AI\\libs']
#       NOT AVAILABLE
#
#     C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\system_info.py:636: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       self.calc_info()
#     lapack_src_info:
#       NOT AVAILABLE
#
#     C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\system_info.py:636: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     C:\Users\cg\anaconda3_AI\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running install
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building py_modules sources
#     building library "npymath" sources
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.27.29110\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -Inumpy\core\src\common -Inumpy\core\src -Inumpy\core -Inumpy\core\src\npymath -Inumpy\core\src\multiarray -Inumpy\core\src\umath -Inumpy\core\src\npysort -IC:\Users\cg\anaconda3_AI\include -IC:\Users\cg\anaconda3_AI\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.27.29110\include -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.6.1\include\um /Tc_configtest.c /Fo_configtest.obj
#     C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.27.29110\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /MANIFEST:EMBED,ID=1 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\VC\Tools\MSVC\14.27.29110\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\NETFXSDK\4.6.1\lib\um\x64 _configtest.obj /OUT:_configtest.exe
#     LINK : fatal error LNK1104: 無法開啟檔案 'kernel32.lib'
#     failure.
#     removing: _configtest.c _configtest.obj _configtest.obj.d
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\setup.py", line 415, in <module>
#         setup_package()
#       File "C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\setup.py", line 407, in setup_package
#         setup(**metadata)
#       File "C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\core.py", line 171, in setup
#         return old_setup(**new_attr)
#       File "C:\Users\cg\anaconda3_AI\lib\site-packages\setuptools\__init__.py", line 165, in setup
#         return distutils.core.setup(**attrs)
#       File "C:\Users\cg\anaconda3_AI\lib\distutils\core.py", line 148, in setup
#         dist.run_commands()
#       File "C:\Users\cg\anaconda3_AI\lib\distutils\dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "C:\Users\cg\anaconda3_AI\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\command\install.py", line 62, in run
#         r = self.setuptools_run()
#       File "C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\command\install.py", line 36, in setuptools_run
#         return distutils_install.run(self)
#       File "C:\Users\cg\anaconda3_AI\lib\distutils\command\install.py", line 545, in run
#         self.run_command('build')
#       File "C:\Users\cg\anaconda3_AI\lib\distutils\cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "C:\Users\cg\anaconda3_AI\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\command\build.py", line 47, in run
#         old_build.run(self)
#       File "C:\Users\cg\anaconda3_AI\lib\distutils\command\build.py", line 135, in run
#         self.run_command(cmd_name)
#       File "C:\Users\cg\anaconda3_AI\lib\distutils\cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "C:\Users\cg\anaconda3_AI\lib\distutils\dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\command\build_src.py", line 148, in run
#         self.build_sources()
#       File "C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\command\build_src.py", line 159, in build_sources
#         self.build_library_sources(*libname_info)
#       File "C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\command\build_src.py", line 292, in build_library_sources
#         sources = self.generate_sources(sources, (lib_name, build_info))
#       File "C:\Users\cg\AppData\Local\Temp\pip-install-ztrvm_2a\numpy\numpy\distutils\command\build_src.py", line 375, in generate_sources
#         source = func(extension, build_dir)
#       File "numpy\core\setup.py", line 667, in get_mathlib_info
#         raise RuntimeError("Broken toolchain: cannot link a simple C program")
#     RuntimeError: Broken toolchain: cannot link a simple C program
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\cg\anaconda3_AI\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\cg\\AppData\\Local\\Temp\\pip-install-ztrvm_2a\\numpy\\setup.py'"'"'; __file__='"'"'C:\\Users\\cg\\AppData\\Local\\Temp\\pip-install-ztrvm_2a\\numpy\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\cg\AppData\Local\Temp\pip-record-m6bh68zq\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\cg\anaconda3_AI\Include\numpy' Check the logs for full command output.

# %%
# !pip install cairosvg

# %%
from deepsvg.svglib.geom import Point
from deepsvg.svglib.svg import SVG
from deepsvg.svglib.svg_path import SVGPath
from deepsvg.svglib.utils import to_gif
from deepsvg.svglib.svg_command import *

from deepsvg.difflib.tensor import SVGTensor
from deepsvg.difflib.utils import *
from deepsvg.difflib.loss import *
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.

# %%
import torch.optim as optim
import IPython.display as ipd
from moviepy.editor import ImageClip, concatenate_videoclips, ipython_display
from cairosvg import svg2png

# %% [markdown]
# # 作業程式碼

# %%
allFileList = os.listdir("docs/長恨歌")


for file in allFileList:

  svg = SVG.load_svg("docs/長恨歌/" + file).normalize().zoom(0.9).canonicalize().simplify_heuristic()

  svg_target = SVGTensor.from_data(svg.to_tensor())
  p_target = svg_target.sample_points()
  #plot_points(p_target, show_color=True)

  shape = SVG.unit_circle().normalize().zoom(0.9).split(4) 
  svg_pred = SVGTensor.from_data(shape.to_tensor())

  p_pred = svg_pred.sample_points()
  #plot_points(p_pred, show_color=True)

  svg_pred.control1.requires_grad_(True)
  svg_pred.control2.requires_grad_(True)
  svg_pred.end_pos.requires_grad_(True)

  optimizer = optim.Adam([svg_pred.control1, svg_pred.control2, svg_pred.end_pos], lr=2)

  img_list = []

  for i in range(250):
      optimizer.zero_grad()

      p_pred = svg_pred.sample_points()
      l = svg_emd_loss(p_pred, p_target)
      l.backward()
      optimizer.step()
      
      if i % 249 == 0:
          img = svg_pred.draw(with_points=True, do_display=False, return_png=True)
          svgtemp = SVG.from_tensor(svg_pred.data)
          svgtemp.save_svg("docs/result/" + file)

  print('docs/result/' + file)
  f = open('docs/result/' + file ,encoding="utf-8")
  line = f.readline()
  svg2png(bytestring = line, write_to= 'docs/result/png/U+'+ file[2:-4] +'.png')
  f.close()
# Out:
# docs/HW7_result/0x5fa1.svg
# docs/HW7_result/0x5b87.svg
# docs/HW7_result/0x7687.svg
# docs/HW7_result/0x694a.svg
# docs/HW7_result/0x570b.svg
# docs/HW7_result/0x50be.svg
# docs/HW7_result/0x8cdc.svg
# docs/HW7_result/0x7738.svg
# docs/HW7_result/0x81ea.svg
# docs/HW7_result/0x6e05.svg
# docs/HW7_result/0x7c89.svg
# docs/HW7_result/0x9078.svg
# docs/HW7_result/0x5a9a.svg
# docs/HW7_result/0x6d74.svg
# docs/HW7_result/0x7b11.svg
# docs/HW7_result/0x96e3.svg
# docs/HW7_result/0x8b58.svg
# docs/HW7_result/0x95a8.svg
# docs/HW7_result/0x9edb.svg
# docs/HW7_result/0x5074.svg
# docs/HW7_result/0x8cea.svg
# docs/HW7_result/0x68c4.svg
# docs/HW7_result/0x6d17.svg
# docs/HW7_result/0x990a.svg
# docs/HW7_result/0x6ed1.svg
# docs/HW7_result/0x6eab.svg
# docs/HW7_result/0x6b61.svg
# docs/HW7_result/0x4f8d.svg
# docs/HW7_result/0x59cb.svg
# docs/HW7_result/0x9592.svg
# docs/HW7_result/0x65e9.svg
# docs/HW7_result/0x59ca.svg
# docs/HW7_result/0x5f9e.svg
# docs/HW7_result/0x5c4b.svg
# docs/HW7_result/0x9189.svg
# docs/HW7_result/0x529b.svg
# docs/HW7_result/0x5ea6.svg
# docs/HW7_result/0x5bf5.svg
# docs/HW7_result/0x7f77.svg
# docs/HW7_result/0x6276.svg
# docs/HW7_result/0x77ed.svg
# docs/HW7_result/0x8eab.svg
# docs/HW7_result/0x5152.svg
# docs/HW7_result/0x904a.svg
# docs/HW7_result/0x5f8c.svg
# docs/HW7_result/0x59b9.svg
# docs/HW7_result/0x6fa4.svg
# docs/HW7_result/0x5bb5.svg
# docs/HW7_result/0x8102.svg
# docs/HW7_result/0x6b65.svg
# docs/HW7_result/0x9e97.svg
# docs/HW7_result/0x5bb4.svg
# docs/HW7_result/0x5b0c.svg
# docs/HW7_result/0x4f73.svg
# docs/HW7_result/0x599d.svg
# docs/HW7_result/0x82e6.svg
# docs/HW7_result/0x6687.svg
# docs/HW7_result/0x627f.svg
# docs/HW7_result/0x6696.svg
# docs/HW7_result/0x4e09.svg
# docs/HW7_result/0x5c08.svg
# docs/HW7_result/0x53ef.svg
# docs/HW7_result/0x7159.svg
# docs/HW7_result/0x9f19.svg
# docs/HW7_result/0x6190.svg
# docs/HW7_result/0x7537.svg
# docs/HW7_result/0x6a02.svg
# docs/HW7_result/0x6f01.svg
# docs/HW7_result/0x6b4c.svg
# docs/HW7_result/0x7236.svg
# docs/HW7_result/0x7af9.svg
# docs/HW7_result/0x5973.svg
# docs/HW7_result/0x6416.svg
# docs/HW7_result/0x5fa9.svg
# docs/HW7_result/0x66f2.svg
# docs/HW7_result/0x5217.svg
# docs/HW7_result/0x7834.svg
# docs/HW7_result/0x5f69.svg
# docs/HW7_result/0x7d72.svg
# docs/HW7_result/0x7de9.svg
# docs/HW7_result/0x51fa.svg
# docs/HW7_result/0x6bcd.svg
# docs/HW7_result/0x6236.svg
# docs/HW7_result/0x8db3.svg
# docs/HW7_result/0x5343.svg
# docs/HW7_result/0x52d5.svg
# docs/HW7_result/0x57ce.svg
# docs/HW7_result/0x9ad8.svg
# docs/HW7_result/0x6162.svg
# docs/HW7_result/0x9a0e.svg
# docs/HW7_result/0x5144.svg
# docs/HW7_result/0x6b62.svg
# docs/HW7_result/0x9a6a.svg
# docs/HW7_result/0x842c.svg
# docs/HW7_result/0x4ee4.svg
# docs/HW7_result/0x4e58.svg
# docs/HW7_result/0x767b.svg
# docs/HW7_result/0x5c11.svg
# docs/HW7_result/0x5948.svg
# docs/HW7_result/0x6c5f.svg
# docs/HW7_result/0x6551.svg
# docs/HW7_result/0x6563.svg
# docs/HW7_result/0x7d22.svg
# docs/HW7_result/0x770b.svg
# docs/HW7_result/0x856d.svg
# docs/HW7_result/0x8840.svg
# docs/HW7_result/0x6d41.svg
# docs/HW7_result/0x5b9b.svg
# docs/HW7_result/0x7ff9.svg
# docs/HW7_result/0x6536.svg
# docs/HW7_result/0x767c.svg
# docs/HW7_result/0x5d4b.svg
# docs/HW7_result/0x50b7.svg
# docs/HW7_result/0x6c34.svg
# docs/HW7_result/0x671d.svg
# docs/HW7_result/0x4e3b.svg
# docs/HW7_result/0x7e08.svg
# docs/HW7_result/0x9918.svg
# docs/HW7_result/0x86fe.svg
# docs/HW7_result/0x7d06.svg
# docs/HW7_result/0x65d7.svg
# docs/HW7_result/0x8ecd.svg
# docs/HW7_result/0x884c.svg
# docs/HW7_result/0x524d.svg
# docs/HW7_result/0x59d4.svg
# docs/HW7_result/0x68e7.svg
# docs/HW7_result/0x5149.svg
# docs/HW7_result/0x6f2b.svg
# docs/HW7_result/0x57c3.svg
# docs/HW7_result/0x65cc.svg
# docs/HW7_result/0x63a9.svg
# docs/HW7_result/0x767e.svg
# docs/HW7_result/0x91cc.svg
# docs/HW7_result/0x96c0.svg
# docs/HW7_result/0x9234.svg
# docs/HW7_result/0x528d.svg
# docs/HW7_result/0x6414.svg
# docs/HW7_result/0x5ce8.svg
# docs/HW7_result/0x516d.svg
# docs/HW7_result/0x8584.svg
# docs/HW7_result/0x548c.svg
# docs/HW7_result/0x8700.svg
# docs/HW7_result/0x66ae.svg
# docs/HW7_result/0x5f97.svg
# docs/HW7_result/0x8272.svg
# docs/HW7_result/0x8056.svg
# docs/HW7_result/0x7709.svg
# docs/HW7_result/0x6db2.svg
# docs/HW7_result/0x5d6c.svg
# docs/HW7_result/0x9aee.svg
# docs/HW7_result/0x5712.svg
# docs/HW7_result/0x5230.svg
# docs/HW7_result/0x7d05.svg
# docs/HW7_result/0x8349.svg
# docs/HW7_result/0x6eff.svg
# docs/HW7_result/0x5761.svg
# docs/HW7_result/0x5167.svg
# docs/HW7_result/0x6843.svg
# docs/HW7_result/0x65b7.svg
# docs/HW7_result/0x82d1.svg
# docs/HW7_result/0x8449.svg
# docs/HW7_result/0x68a7.svg
# docs/HW7_result/0x81e3.svg
# docs/HW7_result/0x8e8a.svg
# docs/HW7_result/0x623f.svg
# docs/HW7_result/0x8072.svg
# docs/HW7_result/0x6383.svg
# docs/HW7_result/0x9580.svg
# docs/HW7_result/0x4f9d.svg
# docs/HW7_result/0x571f.svg
# docs/HW7_result/0x6ce5.svg
# docs/HW7_result/0x5782.svg
# docs/HW7_result/0x8299.svg
# docs/HW7_result/0x5c0d.svg
# docs/HW7_result/0x9867.svg
# docs/HW7_result/0x5357.svg
# docs/HW7_result/0x8e87.svg
# docs/HW7_result/0x6912.svg
# docs/HW7_result/0x9f8d.svg
# docs/HW7_result/0x6771.svg
# docs/HW7_result/0x6b78.svg
# docs/HW7_result/0x6c60.svg
# docs/HW7_result/0x99ac.svg
# docs/HW7_result/0x767d.svg
# docs/HW7_result/0x4fe1.svg
# docs/HW7_result/0x67f3.svg
# docs/HW7_result/0x592e.svg
# docs/HW7_result/0x79cb.svg
# docs/HW7_result/0x9762.svg
# docs/HW7_result/0x984f.svg
# docs/HW7_result/0x674e.svg
# docs/HW7_result/0x84c9.svg
# docs/HW7_result/0x6cbe.svg
# docs/HW7_result/0x8178.svg
# docs/HW7_result/0x6850.svg
# docs/HW7_result/0x4f55.svg
# docs/HW7_result/0x65cb.svg
# docs/HW7_result/0x5f1f.svg
# docs/HW7_result/0x968e.svg
# docs/HW7_result/0x87a2.svg
# docs/HW7_result/0x5a25.svg
# docs/HW7_result/0x9752.svg
# docs/HW7_result/0x6084.svg
# docs/HW7_result/0x98db.svg
# docs/HW7_result/0x963f.svg
# docs/HW7_result/0x76e3.svg
# docs/HW7_result/0x8001.svg
# docs/HW7_result/0x71c8.svg
# docs/HW7_result/0x5b64.svg
# docs/HW7_result/0x7136.svg
# docs/HW7_result/0x6311.svg
# docs/HW7_result/0x5915.svg
# docs/HW7_result/0x611f.svg
# docs/HW7_result/0x5e74.svg
# docs/HW7_result/0x6b32.svg
# docs/HW7_result/0x9b44.svg
# docs/HW7_result/0x7fe1.svg
# docs/HW7_result/0x909b.svg
# docs/HW7_result/0x9d1b.svg
# docs/HW7_result/0x8993.svg
# docs/HW7_result/0x8aa0.svg
# docs/HW7_result/0x7cbe.svg
# docs/HW7_result/0x66d9.svg
# docs/HW7_result/0x5ba2.svg
# docs/HW7_result/0x60a0.svg
# docs/HW7_result/0x521d.svg
# docs/HW7_result/0x90fd.svg
# docs/HW7_result/0x81f4.svg
# docs/HW7_result/0x9042.svg
# docs/HW7_result/0x9072.svg
# docs/HW7_result/0x7720.svg
# docs/HW7_result/0x601d.svg
# docs/HW7_result/0x971c.svg
# docs/HW7_result/0x5bd2.svg
# docs/HW7_result/0x672a.svg
# docs/HW7_result/0x887e.svg
# docs/HW7_result/0x8ab0.svg
# docs/HW7_result/0x8f3e.svg
# docs/HW7_result/0x661f.svg
# docs/HW7_result/0x803f.svg
# docs/HW7_result/0x51b7.svg
# docs/HW7_result/0x65b9.svg
# docs/HW7_result/0x70ba.svg
# docs/HW7_result/0x4ee5.svg
# docs/HW7_result/0x7fe0.svg
# docs/HW7_result/0x9d26.svg
# docs/HW7_result/0x74e6.svg
# docs/HW7_result/0x6cb3.svg
# docs/HW7_result/0x9418.svg
# docs/HW7_result/0x9d3b.svg
# docs/HW7_result/0x9f13.svg
# docs/HW7_result/0x7d93.svg
# docs/HW7_result/0x66fe.svg
# docs/HW7_result/0x58eb.svg
# docs/HW7_result/0x8207.svg
# docs/HW7_result/0x80fd.svg
# docs/HW7_result/0x5171.svg
# docs/HW7_result/0x6b7b.svg
# docs/HW7_result/0x5e33.svg
# docs/HW7_result/0x53c3.svg
# docs/HW7_result/0x9053.svg
# docs/HW7_result/0x53e9.svg
# docs/HW7_result/0x8f49.svg
# docs/HW7_result/0x5bb6.svg
# docs/HW7_result/0x6f22.svg
# docs/HW7_result/0x4e94.svg
# docs/HW7_result/0x5954.svg
# docs/HW7_result/0x6c23.svg
# docs/HW7_result/0x65b0.svg
# docs/HW7_result/0x96d9.svg
# docs/HW7_result/0x5c71.svg
# docs/HW7_result/0x6d77.svg
# docs/HW7_result/0x73e0.svg
# docs/HW7_result/0x96fb.svg
# docs/HW7_result/0x5165.svg
# docs/HW7_result/0x78a7.svg
# docs/HW7_result/0x6a13.svg
# docs/HW7_result/0x6607.svg
# docs/HW7_result/0x7a7a.svg
# docs/HW7_result/0x652c.svg
# docs/HW7_result/0x73b2.svg
# docs/HW7_result/0x96ea.svg
# docs/HW7_result/0x83ef.svg
# docs/HW7_result/0x5831.svg
# docs/HW7_result/0x8c8c.svg
# docs/HW7_result/0x865b.svg
# docs/HW7_result/0x4e4b.svg
# docs/HW7_result/0x96f2.svg
# docs/HW7_result/0x74cf.svg
# docs/HW7_result/0x9a5a.svg
# docs/HW7_result/0x4e5d.svg
# docs/HW7_result/0x7e39.svg
# docs/HW7_result/0x843d.svg
# docs/HW7_result/0x5ffd.svg
# docs/HW7_result/0x8fe4.svg
# docs/HW7_result/0x5b57.svg
# docs/HW7_result/0x95d5.svg
# docs/HW7_result/0x897f.svg
# docs/HW7_result/0x662f.svg
# docs/HW7_result/0x5f8a.svg
# docs/HW7_result/0x5f98.svg
# docs/HW7_result/0x5dee.svg
# docs/HW7_result/0x5922.svg
# docs/HW7_result/0x7b94.svg
# docs/HW7_result/0x5176.svg
# docs/HW7_result/0x5c0f.svg
# docs/HW7_result/0x6210.svg
# docs/HW7_result/0x9280.svg
# docs/HW7_result/0x63a8.svg
# docs/HW7_result/0x5c4f.svg
# docs/HW7_result/0x6392.svg
# docs/HW7_result/0x958b.svg
# docs/HW7_result/0x904d.svg
# docs/HW7_result/0x6243.svg
# docs/HW7_result/0x9b42.svg
# docs/HW7_result/0x9090.svg
# docs/HW7_result/0x592a.svg
# docs/HW7_result/0x99ad.svg
# docs/HW7_result/0x5982.svg
# docs/HW7_result/0x4f7f.svg
# docs/HW7_result/0x5b50.svg
# docs/HW7_result/0x8d77.svg
# docs/HW7_result/0x591a.svg
# docs/HW7_result/0x9b22.svg
# docs/HW7_result/0x5ec2.svg
# docs/HW7_result/0x805e.svg
# docs/HW7_result/0x771f.svg
# docs/HW7_result/0x819a.svg
# docs/HW7_result/0x504f.svg
# docs/HW7_result/0x7aae.svg
# docs/HW7_result/0x7d04.svg
# docs/HW7_result/0x6795.svg
# docs/HW7_result/0x7686.svg
# docs/HW7_result/0x7dbd.svg
# docs/HW7_result/0x6cc9.svg
# docs/HW7_result/0x6c42.svg
# docs/HW7_result/0x95a3.svg
# docs/HW7_result/0x6df1.svg
# docs/HW7_result/0x4e03.svg
# docs/HW7_result/0x84ec.svg
# docs/HW7_result/0x8b1d.svg
# docs/HW7_result/0x77e5.svg
# docs/HW7_result/0x4f46.svg
# docs/HW7_result/0x5bb9.svg
# docs/HW7_result/0x52e4.svg
# docs/HW7_result/0x91cd.svg
# docs/HW7_result/0x51a0.svg
# docs/HW7_result/0x97f3.svg
# docs/HW7_result/0x4eba.svg
# docs/HW7_result/0x5c07.svg
# docs/HW7_result/0x8a5e.svg
# docs/HW7_result/0x8882.svg
# docs/HW7_result/0x5b89.svg
# docs/HW7_result/0x88f3.svg
# docs/HW7_result/0x9593.svg
# docs/HW7_result/0x611b.svg
# docs/HW7_result/0x5225.svg
# docs/HW7_result/0x4e0b.svg
# docs/HW7_result/0x591c.svg
# docs/HW7_result/0x98c4.svg
# docs/HW7_result/0x7747.svg
# docs/HW7_result/0x4e00.svg
# docs/HW7_result/0x6dda.svg
# docs/HW7_result/0x95cc.svg
# docs/HW7_result/0x4e0a.svg
# docs/HW7_result/0x4f86.svg
# docs/HW7_result/0x5bc2.svg
# docs/HW7_result/0x534a.svg
# docs/HW7_result/0x64d8.svg
# docs/HW7_result/0x9ec3.svg
# docs/HW7_result/0x5802.svg
# docs/HW7_result/0x96e8.svg
# docs/HW7_result/0x662d.svg
# docs/HW7_result/0x6625.svg
# docs/HW7_result/0x8209.svg
# docs/HW7_result/0x7ffc.svg
# docs/HW7_result/0x820a.svg
# docs/HW7_result/0x5408.svg
# docs/HW7_result/0x7fbd.svg
# docs/HW7_result/0x5e36.svg
# docs/HW7_result/0x4f3c.svg
# docs/HW7_result/0x542b.svg
# docs/HW7_result/0x738b.svg
# docs/HW7_result/0x5805.svg
# docs/HW7_result/0x65e5.svg
# docs/HW7_result/0x80a1.svg
# docs/HW7_result/0x4f5c.svg
# docs/HW7_result/0x79c1.svg
# docs/HW7_result/0x91f5.svg
# docs/HW7_result/0x8863.svg
# docs/HW7_result/0x5206.svg
# docs/HW7_result/0x7336.svg
# docs/HW7_result/0x4e2d.svg
# docs/HW7_result/0x91d1.svg
# docs/HW7_result/0x82b1.svg
# docs/HW7_result/0x7389.svg
# docs/HW7_result/0x6bbf.svg
# docs/HW7_result/0x6bb7.svg
# docs/HW7_result/0x5bc4.svg
# docs/HW7_result/0x6247.svg
# docs/HW7_result/0x5e72.svg
# docs/HW7_result/0x6069.svg
# docs/HW7_result/0x6559.svg
# docs/HW7_result/0x541b.svg
# docs/HW7_result/0x898b.svg
# docs/HW7_result/0x81e8.svg
# docs/HW7_result/0x89ba.svg
# docs/HW7_result/0x8868.svg
# docs/HW7_result/0x5bde.svg
# docs/HW7_result/0x6574.svg
# docs/HW7_result/0x7559.svg
# docs/HW7_result/0x8a9e.svg
# docs/HW7_result/0x53bb.svg
# docs/HW7_result/0x5fc3.svg
# docs/HW7_result/0x832b.svg
# docs/HW7_result/0x6703.svg
# docs/HW7_result/0x68a8.svg
# docs/HW7_result/0x7761.svg
# docs/HW7_result/0x56de.svg
# docs/HW7_result/0x4ed9.svg
# docs/HW7_result/0x51dd.svg
# docs/HW7_result/0x5439.svg
# docs/HW7_result/0x840a.svg
# docs/HW7_result/0x923f.svg
# docs/HW7_result/0x60df.svg
# docs/HW7_result/0x98a8.svg
# docs/HW7_result/0x671b.svg
# docs/HW7_result/0x88cf.svg
# docs/HW7_result/0x8a93.svg
# docs/HW7_result/0x9727.svg
# docs/HW7_result/0x982d.svg
# docs/HW7_result/0x8655.svg
# docs/HW7_result/0x5bae.svg
# docs/HW7_result/0x5169.svg
# docs/HW7_result/0x5bf0.svg
# docs/HW7_result/0x967d.svg
# docs/HW7_result/0x6708.svg
# docs/HW7_result/0x6bd4.svg
# docs/HW7_result/0x5875.svg
# docs/HW7_result/0x6e3a.svg
# docs/HW7_result/0x7269.svg
# docs/HW7_result/0x821e.svg
# docs/HW7_result/0x9713.svg
# docs/HW7_result/0x751f.svg
# docs/HW7_result/0x76f8.svg
# docs/HW7_result/0x60c5.svg
# docs/HW7_result/0x4e0d.svg
# docs/HW7_result/0x7d55.svg
# docs/HW7_result/0xff0c.svg
# docs/HW7_result/0x7406.svg
# docs/HW7_result/0x9ce5.svg
# docs/HW7_result/0x7232.svg
# docs/HW7_result/0x7121.svg
# docs/HW7_result/0x5728.svg
# docs/HW7_result/0x9023.svg
# docs/HW7_result/0x7dbf.svg
# docs/HW7_result/0x3002.svg
# docs/HW7_result/0x6709.svg
# docs/HW7_result/0x6b64.svg
# docs/HW7_result/0x76e1.svg
# docs/HW7_result/0x5929.svg
# docs/HW7_result/0x5730.svg
# docs/HW7_result/0x679d.svg
# docs/HW7_result/0x9577.svg
# docs/HW7_result/0x6642.svg
# docs/HW7_result/0x4e45.svg
# docs/HW7_result/0x6068.svg
# docs/HW7_result/0x9858.svg
# docs/HW7_result/0x671f.svg
